# %% [markdown]
# ## Unsupervised Learning
# - learning form unlabelled data
# - unsupervised learning algorithms try to find structure within the data sets
# - one example of clustering algorithm is the **K-Means** algorithm

# %% [markdown]
# # K_MEANS
# - applied to data that has a smaller number of dimensions, numeric, and its continous
# - e.g. customer segmentaion, public transport analysis
# - think of scenario where you want to make groups of similar things from a random collection of things
# #### Applications
#     - Document classification - creating vectors from words
#     - Delivery store optimization - optimize launch locations
#     - cluster segmentation
#     - insurance fraud detection - data points that are close to previously identified cluseters of fraud.
#     - Cakk record detain analysis

# %% [markdown]
# ## Intuition
#
# Lets say we want to classify the below data set into 2 clusters

# %%
from IPython.display import Image
Image(filename="img/kmeansalgolstart.png", width=500, height=400)

# %%
- kmeans is composed of 2 steps:
    - the first is a cluster assignment step
    - the second is move cluster step

# %%
from IPython.display import Image
Image(filename="img/kmeansfirstcluster.png", width=500, height=400)

# %%
For the second step

# %%
Image(filename="img/kmeansMoveCluster.png", width=500, height=400)

# %%
Image(filename="img/kmeansfinalcluster.png", width=500, height=400)

# %%
paramers to K-means:
    K number of clusters
    unlabeled training set x

# %%
the algorithm

# %%
Image(filename="img/kmeansAlgorithm.png", width=500, height=400)

# %% [markdown]
# # Optimization Objective
#
# what cost function is being optimized for k-means algol
# why ? helps in debugging

# %%
Image(filename="img/kmeansobjective.png", width=500, height=400)

# %% [markdown]
# the cost function is optimized with respect to 2 parameters the
# - the cluster assignment aims at optimizing the cost function with respect to c's
# - the move cluster centroid step aimgs at optimizing the cost function with respect to the cluster centroid positions
# - aplot of the cost function against through iterations of k-means should always be reducing

# %% [markdown]
# # How do we choose k clusters
#
# ## Randomly picking examples
#
# Randomly pick k examples where k < m
# use the ppicked examples as the cluster centroids
# nb: wrong choice of examples could mean kmeans can get stuck at local optima

# %%
from IPython.display import Image
Image(filename="img/kmeanslocaloptima.png", width=500, height=400)

# %%
so how do we prevent getting stuck at local optima:
    - initialize k clusters several times, compare the distortion function
    - this works better for lowwer number of clusters.

# %%
# How to choose number of clusters

- deducing from visualizing the data e.g.
 how many clusters do you see below

# %%
from IPython.display import Image
Image(filename="img/kvalue.png", width=500, height=400)

# %%
- A better method would be using the elbow method

# %%
from IPython.display import Image
Image(filename="img/kmeanselbow.png", width=500, height=400)

# %%
- Another way to choose number of clusters is to think about the downstream purpose e.g.

# %%
from IPython.display import Image
Image(filename="img/kmeansdownstream.png", width=500, height=400)

# %% [markdown]
# # Anomaly detection overview
#
# fine line between supervised and unsupervised
# given the training data we build a model P(X) whereby
# givena new piece of data we can calculate the
# p(xsample) and see if its below a certain threshold
#
# ## Applications
#     - Fraud Detction say on a website
#         - typing speed
#         - login counts
#         - pages visited
#     - Manufacturing
#
# the model for getting the P(x|y) can be a gaussiaon model where anomolous examples are usually away from the mean

# %%
Image(filename="img/gaussian.png", width=500, height=400)

# %%
# Recommender systems

2 types:
    content-based:
        - objective learn parameters for each user
        - given the feature set of the things that they have so far rated
        
    collaborative filtering:
        - objective: to learnn the features of an item given
            the likes and dislikes of a user and the rating of the respective item

# %%
Image(filename="img/contentBased.png", width=500, height=400)
